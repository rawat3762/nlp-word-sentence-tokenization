# %%
#Tokenization
#word tokenization
#sent tokenization

# %%
x = "NLP enhances data analysis by enabling the. extraction of insights from unstructured. text data, such as customer reviews, social media posts and news articles. By using text mining techniques, .NLP can identify patterns, trends and sentiments that are not immediately obvious in large datasets. Sentiment analysis enables the extraction of subjective qualities, attitudes, .emotions, sarcasm, confusion or suspicion from text. This is often used for routing communications to the system or the person most likely to make the next response."

# %%
x
# Out:
# 'NLP enhances data analysis by enabling the. extraction of insights from unstructured. text data, such as customer reviews, social media posts and news articles. By using text mining techniques, .NLP can identify patterns, trends and sentiments that are not immediately obvious in large datasets. Sentiment analysis enables the extraction of subjective qualities, attitudes, .emotions, sarcasm, confusion or suspicion from text. This is often used for routing communications to the system or the person most likely to make the next response.'

# %%
from nltk.tokenize import word_tokenize , sent_tokenize

# %%
word = word_tokenize(x)
word
# Out:
# ['NLP',
#  'enhances',
#  'data',
#  'analysis',
#  'by',
#  'enabling',
#  'the',
#  '.',
#  'extraction',
#  'of',
#  'insights',
#  'from',
#  'unstructured',
#  '.',
#  'text',
#  'data',
#  ',',
#  'such',
#  'as',
#  'customer',
#  'reviews',
#  ',',
#  'social',
#  'media',
#  'posts',
#  'and',
#  'news',
#  'articles',
#  '.',
#  'By',
#  'using',
#  'text',
#  'mining',
#  'techniques',
#  ',',
#  '.NLP',
#  'can',
#  'identify',
#  'patterns',
#  ',',
#  'trends',
#  'and',
#  'sentiments',
#  'that',
#  'are',
#  'not',
#  'immediately',
#  'obvious',
#  'in',
#  'large',
#  'datasets',
#  '.',
#  'Sentiment',
#  'analysis',
#  'enables',
#  'the',
#  'extraction',
#  'of',
#  'subjective',
#  'qualities',
#  ',',
#  'attitudes',
#  ',',
#  '.emotions',
#  ',',
#  'sarcasm',
#  ',',
#  'confusion',
#  'or',
#  'suspicion',
#  'from',
#  'text',
#  '.',
#  'This',
#  'is',
#  'often',
#  'used',
#  'for',
#  'routing',
#  'communications',
#  'to',
#  'the',
#  'system',
#  'or',
#  'the',
#  'person',
#  'most',
#  'likely',
#  'to',
#  'make',
#  'the',
#  'next',
#  'response',
#  '.']

# %%
print(word,end='')
# Out:
# ['NLP', 'enhances', 'data', 'analysis', 'by', 'enabling', 'the', '.', 'extraction', 'of', 'insights', 'from', 'unstructured', '.', 'text', 'data', ',', 'such', 'as', 'customer', 'reviews', ',', 'social', 'media', 'posts', 'and', 'news', 'articles', '.', 'By', 'using', 'text', 'mining', 'techniques', ',', '.NLP', 'can', 'identify', 'patterns', ',', 'trends', 'and', 'sentiments', 'that', 'are', 'not', 'immediately', 'obvious', 'in', 'large', 'datasets', '.', 'Sentiment', 'analysis', 'enables', 'the', 'extraction', 'of', 'subjective', 'qualities', ',', 'attitudes', ',', '.emotions', ',', 'sarcasm', ',', 'confusion', 'or', 'suspicion', 'from', 'text', '.', 'This', 'is', 'often', 'used', 'for', 'routing', 'communications', 'to', 'the', 'system', 'or', 'the', 'person', 'most', 'likely', 'to', 'make', 'the', 'next', 'response', '.']

# %%
sent = sent_tokenize(x)
sent
# Out:
# ['NLP enhances data analysis by enabling the.',
#  'extraction of insights from unstructured.',
#  'text data, such as customer reviews, social media posts and news articles.',
#  'By using text mining techniques, .NLP can identify patterns, trends and sentiments that are not immediately obvious in large datasets.',
#  'Sentiment analysis enables the extraction of subjective qualities, attitudes, .emotions, sarcasm, confusion or suspicion from text.',
#  'This is often used for routing communications to the system or the person most likely to make the next response.']

# %%
for i in sent:
    print(i)
    print()
# Out:
# NLP enhances data analysis by enabling the.
#
# extraction of insights from unstructured.
#
# text data, such as customer reviews, social media posts and news articles.
#
# By using text mining techniques, .NLP can identify patterns, trends and sentiments that are not immediately obvious in large datasets.
#
# Sentiment analysis enables the extraction of subjective qualities, attitudes, .emotions, sarcasm, confusion or suspicion from text.
#
# This is often used for routing communications to the system or the person most likely to make the next response.
